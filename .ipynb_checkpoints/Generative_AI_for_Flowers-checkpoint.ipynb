# %%
# from tensorflow import keras
# import tensorflow_datasets as tfds
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# []

# %% [raw]
# Создаём датасет с цветочками

# %%
# Константы
img_side = 192

# Разбиваем датасет на тренировочную группу и группу валидации
def init_data_with_batch_size(batch_size):
    global train_data
    train_data = tf.keras.utils.image_dataset_from_directory(
        "flowers",
        image_size=(img_side, img_side),
        shuffle=True,
        batch_size=batch_size,
    )

    # Убираем лейблы (т.к. у нас задача не распознавать изображения)
    train_data = train_data.map(lambda x, y: (x/255.0, x/255.0))

    return train_data

# %% [markdown]
# Модель

# %%
from keras.layers import (Input, Dense, Conv2D, Conv2DTranspose, BatchNormalization, UpSampling2D,
                          Dropout, Flatten, Reshape, Lambda, MaxPool2D, Concatenate, add)
from keras.models import Model
from keras.optimizers import RMSprop, Adam
from keras import backend as K

# Константы
filters = 64
hidden_units = 64 * 9
core_size = (3, 3)

# Энкодер
input_img = Input(shape=(img_side, img_side, 3))
# Чтобы первый слой мог сложиться со следующим (при помощи add([x_temp, x]) )
x_temp = BatchNormalization()(input_img)
x_temp = Conv2D(filters, core_size)(x_temp)

for i in range(1, 6):
    x = BatchNormalization()(x_temp)
    x = Conv2D(filters*i, core_size, activation="relu", padding="same")(x)
    x = Conv2D(filters*i, core_size, activation="relu", padding="same")(x)
    x = BatchNormalization()(x)
    x = Conv2D(filters*i, core_size, activation="relu", padding="same")(x)
    x = Conv2D(filters*1, core_size, activation="relu", padding="same")(x)

    x_temp = add([x_temp, x])
    x_temp = MaxPool2D((2, 2))(x_temp)


x = BatchNormalization()(x_temp)
x = Flatten()(x)
x = Dense(hidden_units, activation="relu")(x)
x = Reshape((int(hidden_units**.5), int(hidden_units**.5), 1))(x)

x = BatchNormalization()(x)
x_temp = Conv2DTranspose(filters, core_size, activation="relu", padding="same")(x)
print(x.shape)

# Декодер
for i in range(4, 0, -1):
    x = BatchNormalization()(x_temp)
    x = Conv2DTranspose(filters*i, core_size, activation="relu", padding="same")(x)
    x = Conv2DTranspose(filters*i, core_size, activation="relu", padding="same")(x)
    x = BatchNormalization()(x)
    x = Conv2DTranspose(filters*i, core_size, activation="relu", padding="same")(x)
    x = Conv2DTranspose(filters*1, core_size, activation="relu", padding="same")(x)

    x_temp = add([x_temp, x])
    x_temp = UpSampling2D((2, 2))(x_temp)


x = Conv2D(3, core_size, activation="sigmoid", padding="same")(x)
output_img = Reshape((img_side, img_side, 3))(x)

# Модель
vae = Model(input_img, output_img, name="vae")

vae.compile(
    optimizer=keras.optimizers.Adam(3e-3),
    loss="binary_crossentropy",
    loss_weights=[1000],
)

vae.summary()
# Out:
# (None, 24, 24, 1)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 59
#      55 # Модель
#      56 vae = Model(input_img, output_img, name="vae")
#      58 vae.compile(
# ---> 59     optimizer=keras.optimizers.Adam(3e-3),
#      60     loss="binary_crossentropy",
#      61     loss_weights=[1000],
#      62 )
#      64 vae.summary()
#
# NameError: name 'keras' is not defined

# %%
train_data = init_data_with_batch_size(5)
vae.fit(
    train_data,
    epochs=50,
)
# Out:
# Found 1671 files belonging to 5 classes.
# Epoch 1/50
#   3/335 [..............................] - ETA: 12:48 - loss: 762.2887
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 train_data = init_data_with_batch_size(5)
# ----> 2 vae.fit(
#       3     train_data,
#       4     epochs=50,
#       5 )
#
# File C:\ProgramData\miniconda3\envs\main\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# ...

# %%
import matplotlib.pyplot as plt
from random import randint
import numpy as np

generated_images = vae.predict(
                        np.array(
                            [i[0][0] for count, i in enumerate(init_data_with_batch_size(1)) if count < 16]
                        ), verbose=False)

num_images = 5

plt.figure(figsize=(20, 10))

for _ in range(num_images):
    random_num = randint(0, 16-1)

    # Оригинальное изображение
    plt.subplot(2, num_images, _ + 1)
    plt.imshow(data[random_num])
    plt.title("Original")
    plt.axis("off")

    # Сгенерированное изображение
    plt.subplot(2, num_images, _ + num_images + 1)
    plt.imshow(generated_images[random_num])
    plt.title("Generated")
    plt.axis("off")
plt.tight_layout()
plt.show()
