# %%
from tensorflow import keras
import tensorflow_datasets as tfds
import tensorflow as tf
from keras.layers import (Input, Dense, Conv2D, Conv2DTranspose, BatchNormalization, UpSampling2D, LeakyReLU,
                          Dropout, Flatten, Reshape, Lambda, MaxPool2D, Concatenate, add, Cropping2D)
from keras.models import Model
from keras.optimizers import RMSprop, Adam
from math import log2
import matplotlib.pyplot as plt
from random import randint
import numpy as np

# %% [raw]
# Создаём датасет с цветочками

# %%
# Константы
img_side = 70

# Разбиваем датасет на тренировочную группу и группу валидации
def init_data_with_batch_size(batch_size):
    global train_data, val_data
    train_data = tf.keras.utils.image_dataset_from_directory(
        # Чтобы использовать "new_flowers" (расширенный датасет) надо запустить increasing_data.py
        "new_flowers",
        image_size=(img_side, img_side),
        shuffle=True,
        batch_size=batch_size,

        subset="training",
        validation_split=0.1,
        seed=123,
    )
    val_data = tf.keras.utils.image_dataset_from_directory(
        # Чтобы использовать "new_flowers" (расширенный датасет) надо запустить increasing_data.py
        "new_flowers",
        image_size=(img_side, img_side),
        shuffle=True,
        batch_size=batch_size,

        subset="validation",
        validation_split=0.1,
        seed=123,
    )

    # Убираем лейблы (т.к. у нас задача не распознавать изображения)
    train_data = train_data.map(lambda x, y: (x/255., x/255.))
    val_data = val_data.map(lambda x, y: (x/255., x/255.))

    return train_data, val_data

# %% [markdown]
# Модель

# %%
# Константы
filters = 32
hidden_units = 4**3  # Только степень 4 (4**?) (Размер "смыслового вектора")
amount_encode_layers = 3
amount_decode_layers = 3
max_boudle_residual_layers = 3  # Сколько слоёв с остаточноым обучением перед уменьшением/увеличением картинки
"""
filters                     Слабое  влияние на количество параметров
hidden_units                Никакое влияние на количество параметров
amount_encode_layers        Сильное влияние на количество параметров
amount_decode_layers        Сильное влияние на количество параметров
max_boudle_residual_layers  Слабое  влияние на количество параметров
"""

core_size = (3, 3)
input_img = Input(shape=(img_side, img_side, 3))

"""Энкодер"""
# Это надо чтобы первый слой мог сложиться со следующим (при помощи add([x_temp, x]) )
# (momentum - параметр расчета скользящего среднего и дисперсии)
x = BatchNormalization(momentum=0.8)(input_img)
x_temp = Conv2D(filters, core_size, activation=LeakyReLU(0.1), padding="same")(x)

for i in range(amount_encode_layers):
    for _ in range(max_boudle_residual_layers):
        x = Conv2D(filters // 2**i, core_size, activation=LeakyReLU(0.1), padding="same")(x_temp)
        x = Conv2D(filters // 2**i, core_size, activation=LeakyReLU(0.1), padding="same")(x)
        x_temp = add([x_temp, x])

    x_temp = MaxPool2D((2, 2))(x_temp)
    x_temp = Conv2D(filters // 2**(i + 1), core_size, activation=LeakyReLU(0.1), padding="same")(x_temp)
    x_temp = BatchNormalization(momentum=0.8)(x_temp)

# Превращаем сжатую картинку в "смысловой вектор"
x = Flatten()(x_temp)
x = Dense(hidden_units, activation=LeakyReLU(0.1))(x)
x = Reshape((int(hidden_units**.5), int(hidden_units**.5), 1))(x)
x_temp = BatchNormalization(momentum=0.8)(x)


"""Декодер"""
# Расширяем карту признаков, увеличиваем картинку и количество фильтров
for i in range(amount_decode_layers, 0, -1):
    for _ in range(max_boudle_residual_layers):
        x = Conv2D(filters // 2**i, core_size, activation=LeakyReLU(0.1), padding="same")(x)
        x = Conv2D(filters // 2**i, core_size, activation=LeakyReLU(0.1), padding="same")(x)
        # x_temp = add([x_temp, x])

    # Чтобы количество фильтров совпадало (для остаточного обучения)
    # x_temp = Conv2DTranspose(filters // 2**(i - 1),
    #                          core_size,
    #                          activation=LeakyReLU(0.1),
    #                          padding="same",
    #                          strides=2
    #                          )(x_temp)
    x = UpSampling2D()(x)
    x_temp = BatchNormalization(momentum=0.8)(x)

# Сжимаем количество фильтров
for i in range(int(log2(filters))):
    x = Conv2D(filters // 2**(i+1), core_size, activation=LeakyReLU(0.1))(x_temp)
    x = Conv2D(filters // 2**(i+1), core_size, activation=LeakyReLU(0.1))(x)
    x_temp = BatchNormalization(momentum=0.8)(x)

# Строим финальное изображение
x = Flatten()(x_temp)
x = Dense(img_side**2*3, activation="sigmoid")(x)
x = Reshape((img_side, img_side, 3))(x)

# # Постобработка (сглаживание шума)
# x = Conv2D(3, (13, 13), activation="sigmoid", padding="same")(x)

# Модель
output_img = x
vae = Model(input_img, output_img, name="vae")
vae.compile(
    optimizer=keras.optimizers.Adam(3e-3),
    loss="binary_crossentropy",
    loss_weights=[1000],
)

vae.summary()
# Out:
# Model: "vae"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 70, 70, 3)]  0           []
#
#  batch_normalization (BatchNorm  (None, 70, 70, 3)   12          ['input_1[0][0]']
#  alization)
#
#  conv2d (Conv2D)                (None, 70, 70, 32)   896         ['batch_normalization[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 70, 70, 32)   9248        ['conv2d[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 70, 70, 32)   9248        ['conv2d_1[0][0]']
#
#  add (Add)                      (None, 70, 70, 32)   0           ['conv2d[0][0]',
#                                                                   'conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 70, 70, 32)   9248        ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 70, 70, 32)   9248        ['conv2d_3[0][0]']
#
#  add_1 (Add)                    (None, 70, 70, 32)   0           ['add[0][0]',
#                                                                   'conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 70, 70, 32)   9248        ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 70, 70, 32)   9248        ['conv2d_5[0][0]']
#
#  add_2 (Add)                    (None, 70, 70, 32)   0           ['add_1[0][0]',
#                                                                   'conv2d_6[0][0]']
#
#  max_pooling2d (MaxPooling2D)   (None, 35, 35, 32)   0           ['add_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 35, 35, 16)   4624        ['max_pooling2d[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 35, 35, 16)  64          ['conv2d_7[0][0]']
#  rmalization)
#
#  conv2d_8 (Conv2D)              (None, 35, 35, 16)   2320        ['batch_normalization_1[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 35, 35, 16)   2320        ['conv2d_8[0][0]']
#
#  add_3 (Add)                    (None, 35, 35, 16)   0           ['batch_normalization_1[0][0]',
#                                                                   'conv2d_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 35, 35, 16)   2320        ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 35, 35, 16)   2320        ['conv2d_10[0][0]']
#
#  add_4 (Add)                    (None, 35, 35, 16)   0           ['add_3[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 35, 35, 16)   2320        ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 35, 35, 16)   2320        ['conv2d_12[0][0]']
#
#  add_5 (Add)                    (None, 35, 35, 16)   0           ['add_4[0][0]',
#                                                                   'conv2d_13[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 17, 17, 16)  0           ['add_5[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 17, 17, 8)    1160        ['max_pooling2d_1[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 17, 17, 8)   32          ['conv2d_14[0][0]']
#  rmalization)
#
#  conv2d_15 (Conv2D)             (None, 17, 17, 8)    584         ['batch_normalization_2[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 17, 17, 8)    584         ['conv2d_15[0][0]']
#
#  add_6 (Add)                    (None, 17, 17, 8)    0           ['batch_normalization_2[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 17, 17, 8)    584         ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 17, 17, 8)    584         ['conv2d_17[0][0]']
#
#  add_7 (Add)                    (None, 17, 17, 8)    0           ['add_6[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 17, 17, 8)    584         ['add_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 17, 17, 8)    584         ['conv2d_19[0][0]']
#
#  add_8 (Add)                    (None, 17, 17, 8)    0           ['add_7[0][0]',
#                                                                   'conv2d_20[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 8, 8, 8)     0           ['add_8[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 8, 8, 4)      292         ['max_pooling2d_2[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 8, 8, 4)     16          ['conv2d_21[0][0]']
#  rmalization)
#
#  flatten (Flatten)              (None, 256)          0           ['batch_normalization_3[0][0]']
#
#  dense (Dense)                  (None, 64)           16448       ['flatten[0][0]']
#
#  reshape (Reshape)              (None, 8, 8, 1)      0           ['dense[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 8, 8, 4)      40          ['reshape[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 8, 8, 4)      148         ['conv2d_22[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 8, 8, 4)      148         ['conv2d_23[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 8, 8, 4)      148         ['conv2d_24[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 8, 8, 4)      148         ['conv2d_25[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 8, 8, 4)      148         ['conv2d_26[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 16, 16, 4)    0           ['conv2d_27[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 16, 16, 8)    296         ['up_sampling2d[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 16, 16, 8)    584         ['conv2d_28[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 16, 16, 8)    584         ['conv2d_29[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 16, 16, 8)    584         ['conv2d_30[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 16, 16, 8)    584         ['conv2d_31[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 16, 16, 8)    584         ['conv2d_32[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 32, 32, 8)   0           ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 16)   1168        ['up_sampling2d_1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_34[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_35[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_36[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_37[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 16)   2320        ['conv2d_38[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 64, 64, 16)  0           ['conv2d_39[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 16)  64          ['up_sampling2d_2[0][0]']
#  rmalization)
#
#  conv2d_40 (Conv2D)             (None, 62, 62, 16)   2320        ['batch_normalization_7[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 60, 60, 16)   2320        ['conv2d_40[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 60, 60, 16)  64          ['conv2d_41[0][0]']
#  rmalization)
#
#  conv2d_42 (Conv2D)             (None, 58, 58, 8)    1160        ['batch_normalization_8[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 56, 56, 8)    584         ['conv2d_42[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 56, 56, 8)   32          ['conv2d_43[0][0]']
#  rmalization)
#
#  conv2d_44 (Conv2D)             (None, 54, 54, 4)    292         ['batch_normalization_9[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 52, 52, 4)    148         ['conv2d_44[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 52, 52, 4)   16          ['conv2d_45[0][0]']
#  ormalization)
#
#  conv2d_46 (Conv2D)             (None, 50, 50, 2)    74          ['batch_normalization_10[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 48, 48, 2)    38          ['conv2d_46[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 48, 48, 2)   8           ['conv2d_47[0][0]']
#  ormalization)
#
#  conv2d_48 (Conv2D)             (None, 46, 46, 1)    19          ['batch_normalization_11[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 44, 44, 1)    10          ['conv2d_48[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 44, 44, 1)   4           ['conv2d_49[0][0]']
#  ormalization)
#
#  flatten_1 (Flatten)            (None, 1936)         0           ['batch_normalization_12[0][0]']
#
#  dense_1 (Dense)                (None, 14700)        28473900    ['flatten_1[0][0]']
#
#  reshape_1 (Reshape)            (None, 70, 70, 3)    0           ['dense_1[0][0]']
#
# ==================================================================================================
# Total params: 28,594,273
# Trainable params: 28,594,117
# Non-trainable params: 156
# __________________________________________________________________________________________________

# %%
train_data, _ = init_data_with_batch_size(128)
vae.fit(
    train_data,
    epochs=100,
)
# Out:
# Found 37799 files belonging to 5 classes.
# Using 34020 files for training.
# Found 37799 files belonging to 5 classes.
# Using 3779 files for validation.
# Epoch 1/100
#  88/266 [========>.....................] - ETA: 1:12 - loss: 613.5624

# %%
def show_row_images(raw_data, title):
    data = np.array([i[0][0] for count, i in enumerate(raw_data)
                         if count < 32])
    generated_images = vae.predict(data, verbose=False)

    num_images = 4

    plt.figure(figsize=(20, 11))

    for _ in range(num_images):
        random_num = randint(0, 32-1)

        # Оригинальное изображение
        plt.subplot(2, num_images, _ + 1)
        plt.imshow(data[random_num])
        plt.gray()
        plt.title(title)
        plt.axis("off")

        # Сгенерированное изображение
        plt.subplot(2, num_images, _ + num_images + 1)
        plt.imshow(generated_images[random_num])
        plt.gray()
        plt.title("Generated")
        plt.axis("off")
    plt.tight_layout()
    plt.show()

_, val_data = init_data_with_batch_size(1)
for _ in range(3):
    show_row_images(val_data, "Validation")

# print(f"Dropout: {dropout}")

train_data, _ = init_data_with_batch_size(1)
for _ in range(3):
    show_row_images(train_data, "Train Data")

# %%
"""Выводим Архитектуру"""
img_file = "architecture.png"
tf.keras.utils.plot_model(vae, to_file=img_file, show_shapes=True, show_layer_names=False)
